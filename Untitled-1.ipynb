# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('college_student_placement_dataset.csv',encoding='latin-1')
df1 = pd.read_csv('crypto_historical_365days.csv',encoding='latin-1')
df.head(100)
# Out:
#    College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0     CLG0030  107             6.61  6.28                     8
# 1     CLG0061   97             5.52  5.37                     8
# 2     CLG0036  109             5.36  5.83                     9
# 3     CLG0055  122             5.47  5.75                     6
# 4     CLG0004   96             7.91  7.69                     7
# ..        ...  ...              ...   ...                   ...
# 95    CLG0043   78             8.07  8.41                     7
# 96    CLG0016  104             8.81  9.26                    10
# 97    CLG0014  103             7.73  7.77                     9
# 98    CLG0074  100             8.14  7.65                     3
# 99    CLG0019   96             9.68  9.19                     1
#
#    Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                     No                       8                     8
# ...

# %%
df.columns
# Out:
# Index(['College_ID', 'IQ', 'Prev_Sem_Result', 'CGPA', 'Academic_Performance',
#        'Internship_Experience', 'Extra_Curricular_Score',
#        'Communication_Skills', 'Projects_Completed', 'Placement'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 10

# %%
df.info
# Out:
# <bound method DataFrame.info of      College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0       CLG0030  107             6.61  6.28                     8
# 1       CLG0061   97             5.52  5.37                     8
# 2       CLG0036  109             5.36  5.83                     9
# 3       CLG0055  122             5.47  5.75                     6
# 4       CLG0004   96             7.91  7.69                     7
# ...         ...  ...              ...   ...                   ...
# 9995    CLG0021  119             8.41  8.29                     4
# 9996    CLG0098   70             9.25  9.34                     7
# 9997    CLG0066   89             6.08  6.25                     3
# 9998    CLG0045  107             8.77  8.92                     3
# 9999    CLG0060  109             9.41  9.77                     8
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0       CLG0030  107             6.61  6.28                     8
# 1       CLG0061   97             5.52  5.37                     8
# 2       CLG0036  109             5.36  5.83                     9
# 3       CLG0055  122             5.47  5.75                     6
# 4       CLG0004   96             7.91  7.69                     7
# ...         ...  ...              ...   ...                   ...
# 9995    CLG0021  119             8.41  8.29                     4
# 9996    CLG0098   70             9.25  9.34                     7
# 9997    CLG0066   89             6.08  6.25                     3
# 9998    CLG0045  107             8.77  8.92                     3
# 9999    CLG0060  109             9.41  9.77                     8
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# ...

# %%
df.isnull().sum()
# Out:
# College_ID                0
# IQ                        0
# Prev_Sem_Result           0
# CGPA                      0
# Academic_Performance      0
# Internship_Experience     0
# Extra_Curricular_Score    0
# Communication_Skills      0
# Projects_Completed        0
# Placement                 0
# dtype: int64

# %%
[i for i in df.columns if df[i].isnull().sum() == 0]
# Out:
# ['College_ID',
#  'IQ',
#  'Prev_Sem_Result',
#  'CGPA',
#  'Academic_Performance',
#  'Internship_Experience',
#  'Extra_Curricular_Score',
#  'Communication_Skills',
#  'Projects_Completed',
#  'Placement']

# %%
sns.heatmap(df.isnull(),yticklabels=False, cbar=False, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df_country = pd.read_excel('crypto_historical_365days.xlsx')
df_country.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df_country = pd.read_excel('crypto_historical_365days.xlsx')
#       2 df_country.head()
#
# File ~/Desktop/career_path_pro /venv/lib/python3.12/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
# ...
